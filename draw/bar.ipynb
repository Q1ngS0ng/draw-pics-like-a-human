# %%
import matplotlib.pyplot as plt

# %%
y = [0.01,0.01,
0.01,
0.004554655870445344,
0.059679037111334,
0.09614421632448673,
0.08058058058058058,
0.049,
0.026013006503251626,
0.0065,
0.0015]

# %%
size = 15
plt.rcParams["font.sans-serif"]=['SimHei']
plt.rcParams["axes.unicode_minus"]=False
plt.grid(axis="y",linestyle='-.', zorder = 0)

x = ["{}%".format(i*10) for i in range(11)]
colors = ["#4E79A7",  "#A0CBE8",  "#F28E2B", "#FFBE7D", "#59A14F", "#8CD17D", "#B6992D", "#F1CE63", "#499894", "#86BCB6", "#E15759", "#E19D9A"] 
colors = ["#4E79A7",  "#A0CBE8",  "#F28E2B", "#002c53", "#ffa510", "#0c84c6", "#ffbd66", "#f74d4d", "#2455a4", "#41b7ac", "#E15759", "#E19D9A"]
for i in range(len(x)):
    plt.bar(x[i],y[i],color=colors[-i], zorder=10) 
plt.ylabel("Successful Rate",fontdict={'size':size})
plt.xlabel("Obfuscation Density",fontdict={'size':size})



plt.savefig('irri_data.pdf')

plt.show()
