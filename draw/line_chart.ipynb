# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 输入数据

# %%
# linear = {'linear0': [0.2857750952243805, 0.9186999797821045],
#  'linear1': [0.28658998012542725, 0.919700026512146],
#  'linear2': [0.2892982065677643, 0.9196000099182129],
#  'linear3': [0.2935592234134674, 0.9189000129699707],
#  'linear4': [0.2991112470626831, 0.9182000160217285],
#  'linear5': [0.3057505190372467, 0.9172000288963318],
#  'linear6': [0.3133162558078766, 0.9156000018119812],
#  'linear7': [0.32168033719062805, 0.9150000214576721],
#  'linear8': [0.33073854446411133, 0.9138000011444092],
#  'linear9': [0.3404063582420349, 0.9129999876022339],
#  'linear10': [0.35061389207839966, 0.911899983882904]}
# relu = {
#  'relu0': [0.14875094592571259, 0.9560999870300293],
#  'relu1': [0.1499246507883072, 0.9553999900817871],
#  'relu2': [0.15358568727970123, 0.9541000127792358],
#  'relu3': [0.15938349068164825, 0.9520000219345093],
#  'relu4': [0.16700197756290436, 0.95169997215271],
#  'relu5': [0.17655706405639648, 0.9495000243186951],
#  'relu6': [0.1879609376192093, 0.9473999738693237],
#  'relu7': [0.2012195736169815, 0.9430999755859375],
#  'relu8': [0.21635127067565918, 0.9405999779701233],
#  'relu9': [0.23317170143127441, 0.9380000233650208],
#  'relu10': [0.25196507573127747, 0.9344000220298767]}
# tanh = {
#  'tanh0': [0.22265438735485077, 0.9330000281333923],
#  'tanh1': [0.2234683632850647, 0.9327999949455261],
#  'tanh2': [0.22457052767276764, 0.9322999715805054],
#  'tanh3': [0.22589223086833954, 0.9314000010490417],
#  'tanh4': [0.22738231718540192, 0.9304999709129333],
#  'tanh5': [0.22900035977363586, 0.9301999807357788],
#  'tanh6': [0.23071442544460297, 0.9300000071525574],
#  'tanh7': [0.23249877989292145, 0.9301999807357788],
#  'tanh8': [0.23433147370815277, 0.9294000267982483],
#  'tanh9': [0.2361956089735031, 0.928600013256073],
#  'tanh10': [0.23807714879512787, 0.9282000064849854]}

linear = [[0.2857750952243805, 0.9186999797821045],
[0.28658998012542725, 0.919700026512146],
[0.2892982065677643, 0.9196000099182129],
[0.2935592234134674, 0.9189000129699707],
[0.2991112470626831, 0.9182000160217285],
[0.3057505190372467, 0.9172000288963318],
[0.3133162558078766, 0.9156000018119812],
[0.32168033719062805, 0.9150000214576721],
[0.33073854446411133, 0.9138000011444092],
[0.3404063582420349, 0.9129999876022339],
[0.35061389207839966, 0.911899983882904]]

relu = [[0.14875094592571259, 0.9560999870300293],
[0.1499246507883072, 0.9553999900817871],
[0.15358568727970123, 0.9541000127792358],
[0.15938349068164825, 0.9520000219345093],
[0.16700197756290436, 0.95169997215271],
[0.17655706405639648, 0.9495000243186951],
[0.1879609376192093, 0.9473999738693237],
[0.2012195736169815, 0.9430999755859375],
[0.21635127067565918, 0.9405999779701233],
[0.23317170143127441, 0.9380000233650208],
[0.25196507573127747, 0.9344000220298767]]

tanh = [[0.22265438735485077, 0.9330000281333923],
[0.2234683632850647, 0.9327999949455261],
[0.22457052767276764, 0.9322999715805054],
[0.22589223086833954, 0.9314000010490417],
[0.22738231718540192, 0.9304999709129333],
[0.22900035977363586, 0.9301999807357788],
[0.23071442544460297, 0.9300000071525574],
[0.23249877989292145, 0.9301999807357788],
[0.23433147370815277, 0.9294000267982483],
[0.2361956089735031, 0.928600013256073],
[0.23807714879512787, 0.9282000064849854]]

# %%
num5 = "#662400"
num2 = "#B33F00"
num3 = "#FF6B1A"
num4 = "#006663"
num1 = "#00B3AD"

# %%
x = ["{}%".format(i*10) for i in range(11)]

y_linear_loss = [1- pos[0] for pos in linear]
y_linear_acc = [linear[0][1] - pos[1] for pos in linear]

y_relu_loss = [1- pos[0] for pos in relu]
y_relu_acc = [relu[0][1] - pos[1] for pos in relu]

y_tanh_loss = [1-pos[0] for pos in tanh]
y_tanh_acc = [tanh[0][1] - pos[1] for pos in tanh]

# %%
plt.plot(x,#x轴
        y_linear_acc,#y轴
        linestyle='-',  # 折线类型
        linewidth=2,  # 折线宽度
        marker = 'o',
        color=num1,  # 折线颜色
        markersize=6,  # 点的大小
        markeredgecolor=num1,  # 点的边框色
        markerfacecolor=num1,  # 点的填充色
        label='Linear'
        )
plt.plot(x,#x轴
        y_relu_acc,#y轴
        linestyle='-',  # 折线类型
        linewidth=2,  # 折线宽度
        marker = 'o',
        color=num2,  # 折线颜色
        markersize=6,  # 点的大小
        markeredgecolor=num2,  # 点的边框色
        markerfacecolor=num2,  # 点的填充色
        label='Relu'
        )
plt.plot(x,#x轴
        y_tanh_acc,#y轴
        linestyle='-',  # 折线类型
        linewidth=2,  # 折线宽度
        marker = 'o',
        color=num3,  # 折线颜色
        markersize=6,  # 点的大小
        markeredgecolor=num3,  # 点的边框色
        markerfacecolor=num3,  # 点的填充色
        label='Tanh'
        )
## plot中参数的含义分别是横轴值，纵轴值，线的形状（'s'方块,'o'实心圆点，'*'五角星   ...，颜色，透明度,线的宽度和标签 ，
plt.grid(linestyle='-.')

plt.legend()  #显示上面的label
plt.xlabel('Obfuscation') #x_label
plt.ylabel('delter acc')#y_label
 
#plt.ylim(-1,1)#仅设置y轴坐标范围
plt.savefig('diff_act.pdf')

plt.show()
